# %% [markdown]
# <a href="https://colab.research.google.com/github/Mstew007/CSC221__Mstew007/blob/main/Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#example from textbook
car = 'Lamborghini'
print("Is car == 'Lamborghini'? I predict True.")
print(car == 'Lamobrghini')
print("\nIs car == 'Honda'? I predict False.")
print(car == 'Honda')
#5.1
car="bmw"
if car=="bmw" :
    print("\ni predict True")
else :
    print("false")

car="volkswagen"
if car=="audi" :
    print("i predict True")
else :
    print("false")

car="Honda"
if car=="Honda" :
    print("i predict True")
else :
    print("false")

car="Ferrari"
if car=="bmw" :
    print("i predict True")
else :
    print("false")

car="Ferrari"
if car=="bmw" :
    print("i predict True")
else :
    print("false")

car="Ferrari"
if car=="Ferrari" :
    print("i predict True")
else :
    print("false")

car="Bugatti"
if car=="bmw" :
    print("i predict True")
else :
    print("false\n")

#5.3 this is the same as there is no output
alien_color = 'green'

if alien_color == 'green':
    print("You earned 5 points!\n")

#5.5
alien_color = 'green'

if alien_color == 'green':
    print("You earned 5 points!\n")

alien_color = 'yellow'

if alien_color == 'green':
    print("You earned 5 points!")
else:
    print("You earned 10 points!\n")

alien_color = 'red'

if alien_color == 'green':
    print("You earned 5 points!")
elif alien_color == 'yellow':
    print("You earned 10 points!")
else:
    print("You earned 15 points!\n")

#5.6
age = 36

if age < 2:
    print("You are a baby")
elif age < 4:
    print("You are a toddler")
elif age < 13:
    print("You are a kid")
elif age < 20:
    print("You are a teenager")
elif age < 65:
    print("You are an adult\n")
else:
    print("You are an elder\n")

#5.7
favorite_fruits = ['apples', 'bananas', 'oranges']

if 'bananas' in favorite_fruits:
    print("I like bananas")
if 'apples' in favorite_fruits:
    print("I like apples")
if 'blueberries' in favorite_fruits:
    print("I like blueberries")
if 'kiwis' in favorite_fruits:
    print("I like kiwis")
if 'oranges' in favorite_fruits:
    print("I like oranges\n")

#5.8
usernames = ['matt', 'joe', 'jack', 'greg', 'admin']

for username in usernames:
    if username == 'admin':
        print("Hello admin, would you like to see a status report?\n")
    else:
        print("Hello " + username + ", thank you for logging in again!\n")

#5.9
usernames = []

if usernames:
    for username in usernames:
        if username == 'admin':
            print("Hello admin, would you like to see a status report?")
        else:
            print("Hello " + username + ", thank you for logging in again!")
else:
    print("We need to find some users!\n")

#5.10
current_users = ['matt', 'joe', 'jack', 'greg', 'admin']
new_users = ['joe', 'ava', 'krista', 'tom', 'matt']

current_users_lower = [user.lower() for user in current_users]

for new_user in new_users:
    if new_user.lower() in current_users_lower:
        print("Sorry " + new_user + ", that name is already taken.\n")
    else:
        print("Awesome, " + new_user + " is still available.\n")

#5.11
numbers = list(range(1,10))

for number in numbers:
    if number == 1:
        print("1st")
    elif number == 2:
        print("2nd")
    elif number == 3:
        print("3rd")
    else:
        print(str(number) + "th")
#5.12 DONE

#For 5.13 I have created a guessing game in my programming lab class using my personal variables so here is my code!(this is only working with IDLE)
import random

class GuessingGame:
    """This is a number guessing game. When an instance is created, it picks a number between 1 and 10, and the user can be asked to guess the number."""
    def init(self):
        """When an instance is created, it picks a number between 1 and 10."""
        #note: This is a syntax error. Complete the following statement!
        self.num = random.randint(1,10)
        self.done = False
        self.max = 5
        self.attempts = 0
    def getRules(self):
        """Returns a string describing what the player should do, suitable to be printed to prompt them to guess a number between 1 and 10."""
        #note: This returns an empty string. Finish the function!
        return "You have 5 guesses to get the right number between 1-10 so Good Luck!"

    def checkGameDone(self):
        """Returns a boolean value, True if the game is over, False otherwise."""
        if(self.done == True):
            return True
        else:
            return False

    def markGameDone(self):
        """Marks the game as being over."""
        self.done = True

    def checkGuess(self, guess):
        """Returns 1 if the guess is greater than the chosen number, -1 if it is smaller, and 0 if it is the same."""
        if(self.num == guess):
            return 0
        elif(self.num < guess):
            return 1
        else:
            return -1
    def playGame(self):
        """Instructs the current game instance to play itself with the user via the terminal (std i/o)."""
        print(self.getRules())
        while self.checkGameDone() == False:
            userNumber = input("Pick The Right Number: ")
            userNumber = int(userNumber)

            result = self.checkGuess(userNumber)
            if(result == 0):
                print("Correct! ")
                self.markGameDone()
            elif(result == 1):
                print("Too High!")
            else:
                print("Too Low!")

            if self.attempts < self.max:
                self.attempts += 1
            else:
                print("You Ran out of guesses! ")
                self.markGameDone()
# if game == "main":
   # game = GuessingGame()
   # game.playGame()
# Out:
# Is car == 'Lamborghini'? I predict True.
# False
#
# Is car == 'Honda'? I predict False.
# False
#
# i predict True
# false
# i predict True
# false
# false
# i predict True
# false
#
# You earned 5 points!
#
# You earned 5 points!
#
# You earned 10 points!
#
# You earned 15 points!
#
# You are an adult
#
# I like bananas
# I like apples
# I like oranges
#
# Hello matt, thank you for logging in again!
#
# Hello joe, thank you for logging in again!
#
# Hello jack, thank you for logging in again!
#
# Hello greg, thank you for logging in again!
#
# Hello admin, would you like to see a status report?
#
# We need to find some users!
#
# Sorry joe, that name is already taken.
#
# Awesome, ava is still available.
#
# Awesome, krista is still available.
#
# Awesome, tom is still available.
#
# Sorry matt, that name is already taken.
#
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th

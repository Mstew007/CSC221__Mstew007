# %% [markdown]
# <a href="https://colab.research.google.com/github/Mstew007/CSC221__Mstew007/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Matthew Stewart
# Assignment 7

#6.1
myself = {
    'first_name': 'matt',
    'last_name': 'stewart',
    'age': 19,
    'city': 'saratoga',
    }

print(myself['first_name'])
print(myself['last_name'])
print(myself['age'])
print(myself['city'])
print("\n")

#6.2
numbers = {
    'matt': 11,
    'ava': 4,
    'joe': 3,
    'tom': 44,
    'jack': 1,
    }

num = numbers['matt']
print("Matt's favorite number is " + str(num))

num = numbers['ava']
print("ava's favorite number is " + str(num))

num = numbers['joe']
print("joe's favorite number is " + str(num))

num = numbers['tom']
print("tom's favorite number is " + str(num))

num = numbers['jack']
print("jack's favorite number is " + str(num))

#6.3
glossary = {
    'string': 'a data structure in Python that represents a sequence of characters',
    'comment': 'the lines in the code that are ignored by the interpreter during the execution of the program',
    'list': ' a data structure in Python that is a mutable, or changeable, ordered sequence of elements',
    'loop': 'repeating something over and over until a particular condition is satisfied',
    'function': " a block of code which only runs when it is called",
    }

word = 'string'
print("\n" + word.title() + ": " + glossary[word])

word = 'comment'
print("\n" + word.title() + ": " + glossary[word])

word = 'list'
print("\n" + word.title() + ": " + glossary[word])

word = 'loop'
print("\n" + word.title() + ": " + glossary[word])

word = 'function'
print("\n" + word.title() + ": " + glossary[word])
print("\n")

#6.4
glossary = {
    'string': 'a data structure in Python that represents a sequence of characters',
    'comment': 'the lines in the code that are ignored by the interpreter during the execution of the program',
    'list': ' a data structure in Python that is a mutable, or changeable, ordered sequence of elements',
    'loop': 'repeating something over and over until a particular condition is satisfied',
    'dictionary': "mutable data structures that allow you to store key-value pairs",
    'key': 'analogous to indexes of a list',
    'value': 'one of the basic things a program works with, like a letter or a number',
    'conditional test': 'Python evaluates the code to see if it meets the specified conditions.',
    'float': 'a function or reusable code in the Python programming language that converts values into floating point numbers',
    'function': " a block of code which only runs when it is called",
    }

for word, definition in glossary.items():
    print("\n" + word.title() + ": " + definition)

#6.11
cities = {
    'New York City': {
        'country': 'New York',
        'population': 8468000,
        'nearby mountains': ' Catskill Mountains',
        },
    'San Francisco': {
        'country': 'California',
        'population': 39240000,
        'nearby mountains': 'Santa Cruz Mountains',
        },
    'Las Vegas': {
        'country': 'Nevada',
        'population': 3140000,
        'nearby mountains': 'Sunrise',
        }
    }

for city, city_info in cities.items():
    country = city_info['country'].title()
    population = city_info['population']
    mountains = city_info['nearby mountains'].title()

    print("\n" + city.title() + " is in " + country)
    print("  It has a population of about " + str(population))
    print("  The " + mountains + " mountains are the closets moutain.")
print("\n")

#6.12
favorite_numbers = {
    'matt': [69, 11],
    'ava': [4, 16, 19],
    'tom': [44, 18],
    }

for name, numbers in favorite_numbers.items():
    print("\n" + name.title() + " likes the following numbers:")
    for number in numbers:
        print("  " + str(number))
# Out:
# matt
# stewart
# 19
# saratoga
#
#
# Matt's favorite number is 11
# ava's favorite number is 4
# joe's favorite number is 3
# tom's favorite number is 44
# jack's favorite number is 1
#
# String: a data structure in Python that represents a sequence of characters
#
# Comment: the lines in the code that are ignored by the interpreter during the execution of the program
#
# List:  a data structure in Python that is a mutable, or changeable, ordered sequence of elements
#
# Loop: repeating something over and over until a particular condition is satisfied
#
# Function:  a block of code which only runs when it is called
#
#
#
# String: a data structure in Python that represents a sequence of characters
#
# Comment: the lines in the code that are ignored by the interpreter during the execution of the program
#
# List:  a data structure in Python that is a mutable, or changeable, ordered sequence of elements
#
# ...

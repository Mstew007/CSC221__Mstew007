# %% [markdown]
# <a href="https://colab.research.google.com/github/Mstew007/CSC221__Mstew007/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#try it yourself problems
#3.1
friends = ['Joe', 'Jack', 'Andrew']

print(friends[0])
print(friends[1])
print(friends[2])

#3.2
friends = ['Joe', 'Jack', 'Andrew']

msg = "\nWhat's Good, " + friends[0].title() + "?"
print(msg)

msg = "What's Good, " + friends[1].title() + "?"
print(msg)

msg = "What's Good, " + friends[2].title() + "?\n"
print(msg)

#3.3
cars = ['Audi', 'Bugatti', 'Lamborghini']

msg = "I would love to drive a " + cars[0].title() + "!"
print(msg)

msg = "I would love to drive a " + cars[1].title() + "!"
print(msg)

msg = "I would love to drive a " + cars[2].title() + "!\n"
print(msg)

#3.4
guest = ['Joe Burrow', 'Tom Brady', 'Pop Smoke']

name = guest[0].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[1].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[2].title()
print(name + ", Would you like to come over for dinner tonight?.\n")

#3.5
name = guest[2].title()
print("\nUnfortunately, " + name + " can't make it to dinner tonight.")

del(guest[2])
guest.insert(2, 'Tee Higgins')

name = guest[0].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[1].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[2].title()
print(name + ", Would you like to come over for dinner tonight?.")

#3.6
print("\nLets invite a lot more people tonight!")
guest.insert(0, 'Joe Mixon')
guest.insert(2, 'Jamarr Chase')
guest.append('Sam Hubbard')

name = guest[0].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[1].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[2].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[3].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[4].title()
print(name + ", Would you like to come over for dinner tonight?.")

name = guest[5].title()
print(name + ", Would you like to come over for dinner tonight?.")

#3.7
print("\nSorry, we can only invite two people to dinner.")

name = guest.pop()
print("Sorry, " + name.title() + " there is no room at the party tonight :(")

name = guest.pop()
print("Sorry, " + name.title() + " there is no room at the party tonight :(")

name = guest.pop()
print("Sorry, " + name.title() + " there is no room at the party tonight :(")

name = guest.pop()
print("Sorry, " + name.title() + " there is no room at the party tonight :(")

name = guest[0].title()
print(name + ", Would you still like to come over for dinner tonight?")

name = guest[1].title()
print(name + ", Would you still like to come over for dinner tonight?\n")

#3.8
locations = ['Hawaii', 'India', 'Russia', 'China', 'Portogul', 'Canada', 'Amazon']

print("Original order:")
print(locations)

print("\nAlphabetical:")
print(sorted(locations))

print("\nOriginal order:")
print(locations)

print("\nReverse alphabetical:")
print(sorted(locations, reverse=True))

print("\nOriginal order:")
print(locations)

print("\nReversed:")
locations.reverse()
print(locations)

print("\nOriginal order:")
locations.reverse()
print(locations)

print("\nAlphabetical")
locations.sort()
print(locations)

print("\nReverse alphabetical")
locations.sort(reverse=True)
print(locations)

#3.9
invitations = ["Joe Burrow", "Joe Mixon", "Jamarr Chase", "Tee Higgins", "Tyler Boyd"]
count_invitations = len(invitations)

print("\n{} people will come to my dinner party".format(count_invitations))

#3a and 3b
multiples = [n for n in range(59, 86) if n % 7 == 0]

print(multiples)
print("\n")
xvalue = [40, 50, 120, -8, 6]
yvalue = []
for x in xvalue:
    y = 7.4 * x + 51
    yvalue.append(y)
for x, y in zip(xvalue, yvalue):
    print(f"For x = {x}, y = {y}")
# Out:
# Joe
# Jack
# Andrew
#
# What's Good, Joe?
# What's Good, Jack?
# What's Good, Andrew?
#
# I would love to drive a Audi!
# I would love to drive a Bugatti!
# I would love to drive a Lamborghini!
#
# Joe Burrow, Would you like to come over for dinner tonight?.
# Tom Brady, Would you like to come over for dinner tonight?.
# Pop Smoke, Would you like to come over for dinner tonight?.
#
#
# Unfortunately, Pop Smoke can't make it to dinner tonight.
# Joe Burrow, Would you like to come over for dinner tonight?.
# Tom Brady, Would you like to come over for dinner tonight?.
# Tee Higgins, Would you like to come over for dinner tonight?.
#
# Lets invite a lot more people tonight!
# Joe Mixon, Would you like to come over for dinner tonight?.
# Joe Burrow, Would you like to come over for dinner tonight?.
# Jamarr Chase, Would you like to come over for dinner tonight?.
# Tom Brady, Would you like to come over for dinner tonight?.
# Tee Higgins, Would you like to come over for dinner tonight?.
# ...
